# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import yaml
year_month_day

pd.set_option('display.max_columns', None)

# %%
df = pd.read_parquet('../data/processed/full_valid.parquet.gzip')

# %%
df.head()
# Out:
#           id  vendor_id     pickup_datetime  passenger_count  \
# 0  id1718206          1 2016-01-05 10:07:14                1
# 1  id1748564          2 2016-01-07 14:38:51                1
# 2  id3792886          1 2016-05-29 22:11:39                2
# 3  id2541269          2 2016-03-01 12:33:26                5
# 4  id3152266          2 2016-04-14 18:52:23                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.990273        40.766647         -73.992729         40.748363
# 1        -73.976311        40.759819         -73.957603         40.779598
# 2        -74.006760        40.749096         -73.972206         40.757252
# 3        -73.982689        40.782124         -73.956490         40.781673
# 4        -73.802071        40.663708         -73.982391         40.766552
#
#   store_and_fwd_flag  year_month_day  daily_preciptation_normal_inches  \
# 0                  N        20160105                              0.12
# ...
