# %%
import pandas as pd
import numpy as np
from datetime import datetime
from feature_engine.wrappers import SklearnTransformerWrapper
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_columns', None)

# %%
df = pd.read_parquet('../data/aggregated/full_valid.parquet.gzip')

# %%
df.head()
# Out:
#   year_month_day  Maximum_max  Minimum_max  passenger_count_sum  \
# 0       20240101         45.0         32.0               9996.0
# 1       20240102         43.0         26.0              10209.0
# 2       20240103         45.0         28.0              10802.0
# 3       20240104         45.0         26.0              13238.0
# 4       20240105         38.0         21.0              13335.0
#
#    day_of_week_max  period_of_day_dawn_sum  period_of_day_morning_sum  \
# 0                0                    2989                       1061
# 1                1                     275                       2094
# 2                2                     308                       2221
# 3                3                     300                       2179
# 4                4                     477                       2399
#
#    period_of_day_afternoon_sum  period_of_day_evening_sum  qty_travels
# 0                         2488                       1575       7625.0
# 1                         3031                       2225       8194.0
# 2                         3244                       2421      10243.0
# 3                         4047                       3717      10261.0
# 4                         3892                       3493       9587.0

# %%
variables = list(set(df.columns) - set(['year_month_day', 'qty_travels']))

# %%
variables
# Out:
# ['period_of_day_dawn_sum',
#  'Maximum_max',
#  'period_of_day_morning_sum',
#  'Minimum_max',
#  'day_of_week_max',
#  'period_of_day_evening_sum',
#  'period_of_day_afternoon_sum',
#  'passenger_count_sum']

# %%
scaler = SklearnTransformerWrapper(StandardScaler(), variables=variables)

# %%
scaler.fit(df)
# Out:
# SklearnTransformerWrapper(transformer=StandardScaler(),
#                           variables=['period_of_day_dawn_sum', 'Maximum_max',
#                                      'period_of_day_morning_sum', 'Minimum_max',
#                                      'day_of_week_max',
#                                      'period_of_day_evening_sum',
#                                      'period_of_day_afternoon_sum',
#                                      'passenger_count_sum'])

# %%
df = scaler.transform(df)

# %%
df.head()
# Out:
#   year_month_day  Maximum_max  Minimum_max  passenger_count_sum  \
# 0       20240101     0.560898     0.427459            -1.216220
# 1       20240102     0.320513    -0.319557            -1.068115
# 2       20240103     0.560898    -0.070552            -0.655786
# 3       20240104     0.560898    -0.319557             1.038031
# 4       20240105    -0.280449    -0.942071             1.105477
#
#    day_of_week_max  period_of_day_dawn_sum  period_of_day_morning_sum  \
# 0        -1.392694                3.352419                  -2.174273
# 1        -0.901155               -0.727122                  -0.056448
# 2        -0.409616               -0.677519                   0.203924
# 3         0.081923               -0.689544                   0.117816
# 4         0.573462               -0.423487                   0.568854
#
#    period_of_day_afternoon_sum  period_of_day_evening_sum  qty_travels
# 0                    -2.819095                  -2.070471       7625.0
# 1                    -1.370601                  -1.199004       8194.0
# 2                    -0.802407                  -0.936223      10243.0
# 3                     1.339657                   0.801347      10261.0
# 4                     0.926183                   0.501026       9587.0
